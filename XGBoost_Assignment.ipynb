# %%
import numpy as np
import pandas as pd

# %%
train_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header = None)
test_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test' , skiprows = 1, header = None)

# %%
col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num','marital_status', 'occupation','relationship', 'race', 'sex',' capital_gain',
'capital_loss', 'hours_per_week', 'native_country', 'wage_class']
train_set.columns = col_labels
test_set.columns = col_labels

# %%
train_set.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital_gain  capital_loss  hours_per_week  native_country wage_class
# 0           2174             0              40   United-States      <=50K
# 1              0             0              13   United-States      <=50K
# 2              0             0              40   United-States      <=50K
# 3              0             0              40   United-States      <=50K
# 4              0             0              40            Cuba      <=50K

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education_num     32561 non-null int64
# marital_status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
#  capital_gain     32561 non-null int64
# capital_loss      32561 non-null int64
# hours_per_week    32561 non-null int64
# native_country    32561 non-null object
# wage_class        32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
train_set.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
#  capital_gain     0
# capital_loss      0
# hours_per_week    0
# native_country    0
# wage_class        0
# dtype: int64

# %%
x=train_set.drop(labels='wage_class', axis=1)
y=train_set['wage_class']

# %%
for i in train_set.columns:
    if train_set[i].dtypes == 'object':
        print(i)
# Out:
# workclass
# education
# marital_status
# occupation
# relationship
# race
# sex
# native_country
# wage_class

# %%
dict_sex = {}
count=0
for i in train_set.sex.unique():
    dict_sex[i]=count
    count+=1

# %%
dict_workclass = {}
count=0
for i in train_set.workclass.unique():
    dict_workclass[i]=count
    count+=1
dict_education = {}
count=0
for i in train_set.education.unique():
    dict_education[i]=count
    count+=1
dict_marital_status = {}
count=0
for i in train_set.marital_status.unique():
    dict_marital_status[i]=count
    count+=1
dict_workclass,dict_education,dict_marital_status
# Out:
# ({' State-gov': 0,
#   ' Self-emp-not-inc': 1,
#   ' Private': 2,
#   ' Federal-gov': 3,
#   ' Local-gov': 4,
#   ' ?': 5,
#   ' Self-emp-inc': 6,
#   ' Without-pay': 7,
#   ' Never-worked': 8},
#  {' Bachelors': 0,
#   ' HS-grad': 1,
#   ' 11th': 2,
#   ' Masters': 3,
#   ' 9th': 4,
#   ' Some-college': 5,
#   ' Assoc-acdm': 6,
#   ' Assoc-voc': 7,
#   ' 7th-8th': 8,
#   ' Doctorate': 9,
#   ' Prof-school': 10,
#   ' 5th-6th': 11,
#   ' 10th': 12,
#   ' 1st-4th': 13,
#   ' Preschool': 14,
#   ' 12th': 15},
#  {' Never-married': 0,
#   ' Married-civ-spouse': 1,
#   ' Divorced': 2,
#   ' Married-spouse-absent': 3,
#   ' Separated': 4,
#   ' Married-AF-spouse': 5,
#   ' Widowed': 6})

# %% [markdown]
# occupation
# relationship
# race
# sex
# native_country
# wage_class

# %%
dict_occupation = {}
count=0
for i in train_set.occupation.unique():
    dict_occupation[i]=count
    count+=1
dict_relationship = {}
count=0
for i in train_set.relationship.unique():
    dict_relationship[i]=count
    count+=1
dict_race = {}
count=0
for i in train_set.race.unique():
    dict_race[i]=count
    count+=1
dict_native_country = {}
count=0
for i in train_set.native_country.unique():
    dict_native_country[i]=count
    count+=1
dict_wage_class = {}
count=0
for i in train_set.wage_class.unique():
    dict_wage_class[i]=count
    count+=1

# %%
train_set['sex']=train_set['sex'].map(dict_sex)

# %% [markdown]
# workclass
# education
# marital_status
# occupation
# relationship
# race
# sex
# native_country
# wage_class

# %%
train_set['workclass']=train_set['workclass'].map(dict_workclass)
train_set['education']=train_set['education'].map(dict_education)
train_set['marital_status']=train_set['marital_status'].map(dict_marital_status)
train_set['occupation']=train_set['occupation'].map(dict_occupation)
train_set['relationship']=train_set['relationship'].map(dict_relationship)
train_set['race']=train_set['race'].map(dict_race)
train_set['native_country']=train_set['native_country'].map(dict_native_country)
train_set['wage_class']=train_set['wage_class'].map(dict_wage_class)

# %%
train_set.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
#  capital_gain     0
# capital_loss      0
# hours_per_week    0
# native_country    0
# wage_class        0
# dtype: int64

# %%
train_set.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          0   77516          0             13               0
# 1   50          1   83311          0             13               1
# 2   38          2  215646          1              9               2
# 3   53          2  234721          2              7               1
# 4   28          2  338409          0             13               1
#
#    occupation  relationship  race  sex   capital_gain  capital_loss  \
# 0           0             0     0    0           2174             0
# 1           1             1     0    0              0             0
# 2           2             0     0    0              0             0
# 3           2             1     1    0              0             0
# 4           3             2     1    1              0             0
#
#    hours_per_week  native_country  wage_class
# 0              40               0           0
# 1              13               0           0
# 2              40               0           0
# 3              40               0           0
# 4              40               1           0

# %%
train_set=train_set.astype(int)

# %%
X=train_set.drop('wage_class',axis=1)
y=train_set['wage_class']

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/b7/5f/857d1fac0c0abca187fad4ca03eb9de3aeb2564cb21d42e2d1645a373d19/xgboost-1.4.0-py3-none-win_amd64.whl (97.8MB)
# Requirement already satisfied (use --upgrade to upgrade): xgboost from https://files.pythonhosted.org/packages/b7/5f/857d1fac0c0abca187fad4ca03eb9de3aeb2564cb21d42e2d1645a373d19/xgboost-1.4.0-py3-none-win_amd64.whl#sha256=0fa40abf2cbb8678bc59e4737d2ea916dd02bbdedb7a8243fce6031e80493e20 in c:\users\karanth\anaconda3\lib\site-packages
# Requirement already satisfied: numpy in c:\users\karanth\anaconda3\lib\site-packages (from xgboost) (1.15.4)
# Requirement already satisfied: scipy in c:\users\karanth\anaconda3\lib\site-packages (from xgboost) (1.1.0)

# %%
from xgboost.sklearn import XGBClassifier
model = XGBClassifier(objective='binary:logistic')
model.fit(train_x, train_y)
# Out:
# C:\Users\karanth\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:50:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#        importance_type='gain', interaction_constraints='',
#        learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=nan, monotone_constraints='()',
#        n_estimators=100, n_jobs=2, num_parallel_tree=1,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#        use_label_encoder=True, validate_parameters=1, verbosity=None)

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(train_x)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(train_y,predictions)
accuracy
# Out:
# 0.9116356616356617

# %%
param_grid={
   
    'learning_rate':[1,0.5,0.1,0.01,0.001],
    'max_depth': [3,5,10,20],
    'n_estimators':[10,50,100,200]
    
}

# %%
from sklearn.model_selection import GridSearchCV
grid= GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid, verbose=3)

# %%
grid.fit(train_x,train_y)
# Out:
# C:\Users\karanth\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\karanth\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [22:53:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\karanth\Anaconda3\lib\site-packages\xgboost\data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.8607528296920243, total=   0.2s
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [22:53:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.8616559168092668, total=   0.1s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [22:53:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.8634987495063841, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=50 ...................
# [22:53:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=50, score=0.8640431692550671, total=   0.6s
# [CV] learning_rate=1, max_depth=3, n_estimators=50 ...................
# [22:53:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=50, score=0.8683690930630512, total=   0.5s
# [CV] learning_rate=1, max_depth=3, n_estimators=50 ...................
# [22:53:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=50, score=0.8661313676451231, total=   0.5s
# [CV] learning_rate=1, max_depth=3, n_estimators=100 ..................
# [22:53:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=100, score=0.8604896025269808, total=   1.4s
# [CV] learning_rate=1, max_depth=3, n_estimators=100 ..................
# [22:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=100, score=0.8641569040410688, total=   1.2s
# [CV] learning_rate=1, max_depth=3, n_estimators=100 ..................
# [22:53:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=100, score=0.8650783203896275, total=   1.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=200 ..................
# [22:53:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=200, score=0.8558831271387207, total=   2.5s
# [CV] learning_rate=1, max_depth=3, n_estimators=200 ..................
# [22:53:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=200, score=0.8600763459260234, total=   2.3s
# [CV] learning_rate=1, max_depth=3, n_estimators=200 ..................
# [22:53:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=3, n_estimators=200, score=0.8591549295774648, total=   2.3s
# [CV] learning_rate=1, max_depth=5, n_estimators=10 ...................
# [22:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=10, score=0.857594103711503, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=10 ...................
# [22:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=10, score=0.8652099512965644, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=10 ...................
# [22:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=10, score=0.8700802948532316, total=   0.2s
# [CV] learning_rate=1, max_depth=5, n_estimators=50 ...................
# [22:53:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=50, score=0.8527244011581995, total=   0.9s
# [CV] learning_rate=1, max_depth=5, n_estimators=50 ...................
# [22:53:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=50, score=0.8570488350664736, total=   0.9s
# [CV] learning_rate=1, max_depth=5, n_estimators=50 ...................
# [22:53:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=50, score=0.8607345004607082, total=   0.8s
# [CV] learning_rate=1, max_depth=5, n_estimators=100 ..................
# [22:53:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=100, score=0.8498289023427218, total=   2.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=100 ..................
# [22:53:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=100, score=0.8548111096485455, total=   1.6s
# [CV] learning_rate=1, max_depth=5, n_estimators=100 ..................
# [22:54:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=100, score=0.855864156904041, total=   1.4s
# [CV] learning_rate=1, max_depth=5, n_estimators=200 ..................
# [22:54:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=200, score=0.8446959726243748, total=   3.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=200 ..................
# [22:54:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=200, score=0.848492826115572, total=   2.7s
# [CV] learning_rate=1, max_depth=5, n_estimators=200 ..................
# [22:54:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=5, n_estimators=200, score=0.8492826115571936, total=   2.9s
# [CV] learning_rate=1, max_depth=10, n_estimators=10 ..................
# [22:54:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=10, score=0.8560147407212424, total=   0.3s
# [CV] learning_rate=1, max_depth=10, n_estimators=10 ..................
# [22:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=10, score=0.8530999078583651, total=   0.3s
# [CV] learning_rate=1, max_depth=10, n_estimators=10 ..................
# [22:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=10, score=0.858628405949717, total=   0.4s
# [CV] learning_rate=1, max_depth=10, n_estimators=50 ..................
# [22:54:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=50, score=0.8477230850223743, total=   1.6s
# [CV] learning_rate=1, max_depth=10, n_estimators=50 ..................
# [22:54:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=50, score=0.8417796498617875, total=   1.7s
# [CV] learning_rate=1, max_depth=10, n_estimators=50 ..................
# [22:54:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=50, score=0.850993813347374, total=   1.7s
# [CV] learning_rate=1, max_depth=10, n_estimators=100 .................
# [22:54:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=100, score=0.843248223216636, total=   3.2s
# [CV] learning_rate=1, max_depth=10, n_estimators=100 .................
# [22:54:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=100, score=0.8390154008161116, total=   3.4s
# [CV] learning_rate=1, max_depth=10, n_estimators=100 .................
# [22:54:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=100, score=0.8516519678820587, total=   3.1s
# [CV] learning_rate=1, max_depth=10, n_estimators=200 .................
# [22:54:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=200, score=0.8470650171097658, total=   5.6s
# [CV] learning_rate=1, max_depth=10, n_estimators=200 .................
# [22:54:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=200, score=0.8388837699091747, total=   6.2s
# [CV] learning_rate=1, max_depth=10, n_estimators=200 .................
# [22:54:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=10, n_estimators=200, score=0.8513887060681848, total=   6.0s
# [CV] learning_rate=1, max_depth=20, n_estimators=10 ..................
# [22:54:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=10, score=0.846933403527244, total=   0.6s
# [CV] learning_rate=1, max_depth=20, n_estimators=10 ..................
# [22:54:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=10, score=0.8449387916282743, total=   0.6s
# [CV] learning_rate=1, max_depth=20, n_estimators=10 ..................
# [22:54:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=10, score=0.8473081479531394, total=   0.8s
# [CV] learning_rate=1, max_depth=20, n_estimators=50 ..................
# [22:54:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=50, score=0.8453540405369834, total=   2.8s
# [CV] learning_rate=1, max_depth=20, n_estimators=50 ..................
# [22:54:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=50, score=0.8494142424641306, total=   3.1s
# [CV] learning_rate=1, max_depth=20, n_estimators=50 ..................
# [22:54:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=50, score=0.8494142424641306, total=   3.1s
# [CV] learning_rate=1, max_depth=20, n_estimators=100 .................
# [22:54:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=100, score=0.8445643590418531, total=   5.8s
# [CV] learning_rate=1, max_depth=20, n_estimators=100 .................
# [22:55:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=100, score=0.8486244570225089, total=   5.0s
# [CV] learning_rate=1, max_depth=20, n_estimators=100 .................
# [22:55:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=100, score=0.8490193497433197, total=   4.9s
# [CV] learning_rate=1, max_depth=20, n_estimators=200 .................
# [22:55:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=200, score=0.8452224269544617, total=   9.9s
# [CV] learning_rate=1, max_depth=20, n_estimators=200 .................
# [22:55:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=200, score=0.8466499934184547, total=   9.7s
# [CV] learning_rate=1, max_depth=20, n_estimators=200 .................
# [22:55:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=1, max_depth=20, n_estimators=200, score=0.8513887060681848, total=   9.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=10 .................
# [22:55:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10, score=0.8507501974203738, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=10 .................
# [22:55:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10, score=0.8499407660918784, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=10 .................
# [22:55:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10, score=0.85849677504278, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=50 .................
# [22:55:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50, score=0.8677283495656751, total=   0.4s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=50 .................
# [22:55:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50, score=0.8698170330393576, total=   0.4s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=50 .................
# [22:55:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50, score=0.8712649730156641, total=   0.4s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=100 ................
# [22:55:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100, score=0.8714135298762832, total=   0.9s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=100 ................
# [22:55:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100, score=0.8685007239699881, total=   0.9s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=100 ................
# [22:55:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100, score=0.8706068184809793, total=   0.9s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=200 ................
# [22:55:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200, score=0.8672018952355883, total=   1.8s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=200 ................
# [22:55:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200, score=0.8666578912728709, total=   1.8s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=200 ................
# [22:55:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200, score=0.8666578912728709, total=   1.7s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=10 .................
# [22:55:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10, score=0.8596999210318504, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=10 .................
# [22:55:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10, score=0.8634987495063841, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=10 .................
# [22:55:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10, score=0.8648150585757536, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=50 .................
# [22:55:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50, score=0.8669386680705449, total=   0.7s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=50 .................
# [22:55:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50, score=0.8677109385283664, total=   0.7s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=50 .................
# [22:55:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50, score=0.8659997367381861, total=   1.2s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=100 ................
# [22:56:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100, score=0.8649644643327191, total=   1.9s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=100 ................
# [22:56:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100, score=0.8625773331578255, total=   1.4s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=100 ................
# [22:56:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100, score=0.8623140713439515, total=   1.5s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=200 ................
# [22:56:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200, score=0.8610160568570676, total=   3.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=200 ................
# [22:56:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200, score=0.8573120968803475, total=   2.8s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=200 ................
# [22:56:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200, score=0.8595498222982756, total=   2.8s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=10 ................
# [22:56:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10, score=0.8632534877599368, total=   0.3s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=10 ................
# [22:56:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10, score=0.8632354876925102, total=   0.3s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=10 ................
# [22:56:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10, score=0.8666578912728709, total=   0.3s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=50 ................
# [22:56:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50, score=0.8589102395367202, total=   1.5s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=50 ................
# [22:56:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50, score=0.85849677504278, total=   1.5s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=50 ................
# [22:56:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50, score=0.8598130841121495, total=   1.5s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=100 ...............
# [22:56:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100, score=0.8607528296920243, total=   3.2s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=100 ...............
# [22:56:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100, score=0.8571804659734106, total=   3.0s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=100 ...............
# [22:56:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100, score=0.8573120968803475, total=   3.1s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=200 ...............
# [22:56:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200, score=0.8543037641484601, total=   5.7s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=200 ...............
# [22:56:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200, score=0.850862182440437, total=   5.8s
# [CV] learning_rate=0.5, max_depth=10, n_estimators=200 ...............
# [22:56:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200, score=0.8563906805317889, total=   5.8s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=10 ................
# [22:56:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10, score=0.8529876283232429, total=   0.7s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=10 ................
# [22:56:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10, score=0.8562590496248519, total=   0.7s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=10 ................
# [22:56:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10, score=0.8591549295774648, total=   0.6s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=50 ................
# [22:56:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50, score=0.8524611739931561, total=   3.0s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=50 ................
# [22:56:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50, score=0.8529682769514282, total=   3.0s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=50 ................
# [22:56:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50, score=0.8578386205080953, total=   3.0s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=100 ...............
# [22:57:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100, score=0.8537773098183733, total=   5.6s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=100 ...............
# [22:57:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100, score=0.8530999078583651, total=   5.6s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=100 ...............
# [22:57:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100, score=0.8553376332762933, total=   5.6s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=200 ...............
# [22:57:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200, score=0.8533824690708081, total=  10.4s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=200 ...............
# [22:57:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200, score=0.8519152296959326, total=  10.5s
# [CV] learning_rate=0.5, max_depth=20, n_estimators=200 ...............
# [22:57:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200, score=0.8545478478346715, total=  10.4s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=10 .................
# [22:57:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10, score=0.8407475651487234, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=10 .................
# [22:57:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10, score=0.8421745425825984, total=   0.1s
# ...
# [CV] learning_rate=0.001, max_depth=5, n_estimators=50 ...............
# [23:02:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50, score=0.848361195208635, total=   0.7s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [23:02:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.846012108449592, total=   1.4s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [23:02:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.8470448861392655, total=   1.4s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [23:02:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.845728577069896, total=   1.4s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [23:02:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.846012108449592, total=   2.9s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [23:02:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.8470448861392655, total=   2.9s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [23:03:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.8453336843490852, total=   2.9s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=10 ..............
# [23:03:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10, score=0.8560147407212424, total=   0.3s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=10 ..............
# [23:03:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10, score=0.8525733842306173, total=   0.3s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=10 ..............
# [23:03:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10, score=0.855864156904041, total=   0.3s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=50 ..............
# [23:03:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50, score=0.8561463543037642, total=   1.6s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=50 ..............
# [23:03:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50, score=0.8541529551138607, total=   1.6s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=50 ..............
# [23:03:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50, score=0.855864156904041, total=   1.7s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=100 .............
# [23:03:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100, score=0.8564095814688076, total=   3.3s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=100 .............
# [23:03:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100, score=0.8548111096485455, total=   3.3s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=100 .............
# [23:03:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100, score=0.8538896932999869, total=   3.5s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=200 .............
# [23:03:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200, score=0.8562779678862859, total=   6.7s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=200 .............
# [23:03:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200, score=0.8530999078583651, total=   6.7s
# [CV] learning_rate=0.001, max_depth=10, n_estimators=200 .............
# [23:03:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200, score=0.8525733842306173, total=   7.0s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=10 ..............
# [23:03:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10, score=0.839036588575941, total=   0.6s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=10 ..............
# [23:03:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10, score=0.8344083190733184, total=   0.6s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=10 ..............
# [23:03:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10, score=0.840463340792418, total=   0.6s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=50 ..............
# [23:03:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50, score=0.8407475651487234, total=   3.3s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=50 ..............
# [23:03:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50, score=0.8370409372120574, total=   3.3s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=50 ..............
# [23:03:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50, score=0.8398051862577333, total=   3.4s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=100 .............
# [23:03:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100, score=0.8428533824690708, total=   6.6s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=100 .............
# [23:04:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100, score=0.840463340792418, total=   6.6s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=100 .............
# [23:04:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100, score=0.840463340792418, total=   6.9s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=200 .............
# [23:04:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200, score=0.8446959726243748, total=  14.6s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=200 .............
# [23:04:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200, score=0.8423061734895353, total=  13.7s
# [CV] learning_rate=0.001, max_depth=20, n_estimators=200 .............
# [23:04:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200, score=0.8424378043964723, total=  13.9s
# [23:05:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed: 11.4min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#        colsample_bynode=None, colsample_bytree=None, gamma=None,
#        gpu_id=None, importance_type='gain', interaction_constraints=None,
#        learning_rate=None, max_delta_step=None, max_depth=None,
#        min_child_w...e,
#        tree_method=None, use_label_encoder=True, validate_parameters=None,
#        verbosity=None),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'learning_rate': [1, 0.5, 0.1, 0.01, 0.001], 'max_depth': [3, 5, 10, 20], 'n_estimators': [10, 50, 100, 200]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}

# %%
new_model=XGBClassifier(learning_rate= 0.1, max_depth= 5, n_estimators= 200)
new_model.fit(train_x, train_y)
# Out:
# [23:05:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#        importance_type='gain', interaction_constraints='',
#        learning_rate=0.1, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=nan, monotone_constraints='()',
#        n_estimators=200, n_jobs=2, num_parallel_tree=1,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#        use_label_encoder=True, validate_parameters=1, verbosity=None)

# %%
y_pred_new = new_model.predict(test_x)
predictions_new = [round(value) for value in y_pred_new]
accuracy_new = accuracy_score(test_y,predictions_new)
accuracy_new
# Out:
# 0.8742962432183438
